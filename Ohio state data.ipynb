# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ohio = pd.DataFrame({'cause of deaths': ['Chronic Disease', 'Unintetional Injuries', 'Alzheimers', 'Infuenza and Pneumonia', 'Sepsis','Others'],
                     'Percentile': [62, 5, 4, 2, 1 , 26]})
ohio
# Out:
#           cause of deaths  Percentile
# 0         Chronic Disease          62
# 1   Unintetional Injuries           5
# 2              Alzheimers           4
# 3  Infuenza and Pneumonia           2
# 4                  Sepsis           1
# 5                  Others          26

# %%
ohio.groupby(['cause of deaths']).sum().plot(kind = 'pie', y = 'Percentile', radius = 2)
# Out:
# <AxesSubplot:ylabel='Percentile'>
